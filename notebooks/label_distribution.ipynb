# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# 100 labels per eg
labels, values = zip(*Counter({'4019': 15749, '4280': 10083, '42731': 9925, 
                          '41401': 9611, '5849': 7114, '25000': 6917, 
                          '2724': 6815, '51881': 5737, '5990': 5073, 
                          '53081': 4886, '2720': 4485, '2859': 4262, 
                          '2449': 3787, '486': 3747, '2851': 3534, 
                          '2762': 3438, '496': 3372, '99592': 3038, 'V5861': 2928, 
                          '0389': 2816, '5070': 2815, '5859': 2698, '311': 2677, 
                          '40390': 2671, '3051': 2611, '412': 2517, '2761': 2391, 
                          '2875': 2390, '41071': 2356, 'V4581': 2285, '4240': 2238, 
                          'V1582': 2194, '5119': 2124, 'V4582': 2098, '40391': 2026, 
                          '78552': 2015, 'V5867': 1998, '4241': 1982, '42789': 1901, 
                          '32723': 1854, '9971': 1790, '5845': 1747, '2760': 1744, '49390': 1703, 
                          '2767': 1702, 'V290': 1197, '7742': 1006, 'V053': 930, 'V3001': 670, 'V3000': 432}).items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.axes().get_xaxis().set_ticks([])
plt.title("Distribution of top 50 labels, max 100 labels per datapoint")
plt.savefig("dist_50_max100.png")
plt.show()

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# 100 labels per eg
labels, values = zip(*Counter({'41401': 2738, '0389': 1555, '41071': 1356, '4241': 886, '51881': 861, 
                               '431': 750, 'V3001': 669, '486': 549, '5070': 500, 'V3000': 432, '4240': 427, 
                               '4280': 424, '5849': 413, 'V3101': 400, '430': 392, '41011': 359, '5789': 359, 
                               '41041': 358, '1983': 289, '5770': 285, '43411': 266, '41519': 263, '43491': 255, 
                               '42731': 246, '99859': 245, '03842': 243, '85221': 236, '25013': 226, '99662': 226, 
                               '42823': 223, '56212': 219, '42833': 207, '49121': 204, '4271': 203, '5712': 196, 
                               '4373': 193, '51884': 189, '4321': 188, '29181': 174, '03849': 174, '99811': 173, 
                               '03811': 153, '85220': 150, '042': 146, '4414': 143, '1623': 143, '5715': 143, 
                               '0380': 140, '43310': 133, 'V3401': 110}).items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.axes().get_xaxis().set_ticks([])
plt.title("Distribution of top 50 labels, max. 1 labels per datapoint")
plt.savefig("dist_50_max1.png")
plt.show()

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# 1 labels per eg
labels, values = zip(*Counter({'41401': 2738, '0389': 1555, '41071': 1356, '4241': 886, 
                               '51881': 861, '431': 750, 'V3001': 669, '486': 549, 
                               'V3000': 432, 'V3101': 400}).items())

indexes = np.arange(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes + width * 0.5, labels)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.axes().get_xaxis().set_ticks([])
plt.title("Distribution of top 10 labels, max. 1 labels per datapoint")
plt.savefig("dist_10_max1.png")
plt.show()

# %%
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt

# 100 labels per eg
labels, values = zip(*Counter( {'Nursing/\nother': 821258, 
                                'Radiology': 378920, 
                                'Nursing': 220758, 
                                'Physician ': 140100,
                                'ECG': 138190, 
                                'Discharge \nsummary': 59652,
                                'Echo': 34037,
                                'Respiratory ': 31667,
                                'Nutrition': 9378,  
                                'General': 8209}).items())

indexes = np.arange(len(labels))
print(len(labels))
width = 1

plt.bar(indexes, values, width)
plt.xticks(indexes - 1 + width * 0.5, labels)
ax = plt.gca()
plt.xticks(rotation=45)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
# plt.axes().get_xaxis().set_ticks([])
plt.title("Top 10 occurring note types")
plt.tight_layout()
plt.savefig("top10notes.png")
plt.show()
# Out:
# 10
